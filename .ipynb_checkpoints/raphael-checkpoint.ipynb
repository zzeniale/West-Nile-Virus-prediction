# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Cleaning-Weather" data-toc-modified-id="Cleaning-Weather-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Cleaning Weather</a></span><ul class="toc-item"><li><span><a href="#Missing-'Tavg'-values" data-toc-modified-id="Missing-'Tavg'-values-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Missing 'Tavg' values</a></span></li><li><span><a href="#Missing-WetBulb-values-and-seeing-correlation-of-Heat/Cool-vs-Tavg" data-toc-modified-id="Missing-WetBulb-values-and-seeing-correlation-of-Heat/Cool-vs-Tavg-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Missing WetBulb values and seeing correlation of Heat/Cool vs Tavg</a></span></li><li><span><a href="#Amount-of-sunlight-hours---just-for-fun?" data-toc-modified-id="Amount-of-sunlight-hours---just-for-fun?-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>Amount of sunlight hours - just for fun?</a></span></li><li><span><a href="#Humidity" data-toc-modified-id="Humidity-1.4"><span class="toc-item-num">1.4&nbsp;&nbsp;</span>Humidity</a></span></li><li><span><a href="#CodeSum" data-toc-modified-id="CodeSum-1.5"><span class="toc-item-num">1.5&nbsp;&nbsp;</span>CodeSum</a></span></li><li><span><a href="#Looking-at-some-other-columns" data-toc-modified-id="Looking-at-some-other-columns-1.6"><span class="toc-item-num">1.6&nbsp;&nbsp;</span>Looking at some other columns</a></span></li><li><span><a href="#Exporting-to-a-dataframe" data-toc-modified-id="Exporting-to-a-dataframe-1.7"><span class="toc-item-num">1.7&nbsp;&nbsp;</span>Exporting to a dataframe</a></span></li></ul></li><li><span><a href="#Cleaning-Train-set" data-toc-modified-id="Cleaning-Train-set-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Cleaning Train set</a></span><ul class="toc-item"><li><span><a href="#Grouping-NumMosquitos-and-assorted-other-columns" data-toc-modified-id="Grouping-NumMosquitos-and-assorted-other-columns-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Grouping NumMosquitos and assorted other columns</a></span></li><li><span><a href="#DBSCAN-to-cluster-by-Latitude,-Longitude,-and-NumMosquitos" data-toc-modified-id="DBSCAN-to-cluster-by-Latitude,-Longitude,-and-NumMosquitos-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>DBSCAN to cluster by Latitude, Longitude, and NumMosquitos</a></span><ul class="toc-item"><li><span><a href="#Checks-for-LatLongs-with-belong-to-more-than-1-cluster" data-toc-modified-id="Checks-for-LatLongs-with-belong-to-more-than-1-cluster-2.2.1"><span class="toc-item-num">2.2.1&nbsp;&nbsp;</span>Checks for LatLongs with belong to more than 1 cluster</a></span></li><li><span><a href="#Check-for-LatLongs-that-are-clustered-all-as-outliers" data-toc-modified-id="Check-for-LatLongs-that-are-clustered-all-as-outliers-2.2.2"><span class="toc-item-num">2.2.2&nbsp;&nbsp;</span>Check for LatLongs that are clustered all as outliers</a></span></li><li><span><a href="#Cleaning-up-clusters-for-mapping" data-toc-modified-id="Cleaning-up-clusters-for-mapping-2.2.3"><span class="toc-item-num">2.2.3&nbsp;&nbsp;</span>Cleaning up clusters for mapping</a></span></li></ul></li></ul></li><li><span><a href="#Cleaning-Test-set" data-toc-modified-id="Cleaning-Test-set-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Cleaning Test set</a></span><ul class="toc-item"><li><span><a href="#Mapping-DBSCAN-cluster-into-test-set" data-toc-modified-id="Mapping-DBSCAN-cluster-into-test-set-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Mapping DBSCAN cluster into test set</a></span></li></ul></li><li><span><a href="#Merging-weather-data-with-train/test-set" data-toc-modified-id="Merging-weather-data-with-train/test-set-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Merging weather data with train/test set</a></span><ul class="toc-item"><li><span><a href="#Function-for-making-rolling-average-of-weather" data-toc-modified-id="Function-for-making-rolling-average-of-weather-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Function for making rolling average of weather</a></span></li><li><span><a href="#Function-to-merge-rolling-average-weather-into-train/test-set" data-toc-modified-id="Function-to-merge-rolling-average-weather-into-train/test-set-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>Function to merge rolling average weather into train/test set</a></span></li></ul></li><li><span><a href="#Preparing-for-modelling" data-toc-modified-id="Preparing-for-modelling-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Preparing for modelling</a></span><ul class="toc-item"><li><span><a href="#Getting-sets-of-X-variables" data-toc-modified-id="Getting-sets-of-X-variables-5.1"><span class="toc-item-num">5.1&nbsp;&nbsp;</span>Getting sets of X variables</a></span></li><li><span><a href="#Preparing-a-dictionary-to-append-model-data" data-toc-modified-id="Preparing-a-dictionary-to-append-model-data-5.2"><span class="toc-item-num">5.2&nbsp;&nbsp;</span>Preparing a dictionary to append model data</a></span></li></ul></li><li><span><a href="#YOLO-time" data-toc-modified-id="YOLO-time-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>YOLO time</a></span></li><li><span><a href="#YOLO...-err..-modelling-time" data-toc-modified-id="YOLO...-err..-modelling-time-7"><span class="toc-item-num">7&nbsp;&nbsp;</span>YOLO... err.. modelling time</a></span></li><li><span><a href="#All-messy-stuff-below-here,-messier-than-above-anyway,-don't-look-and-don't-judge" data-toc-modified-id="All-messy-stuff-below-here,-messier-than-above-anyway,-don't-look-and-don't-judge-8"><span class="toc-item-num">8&nbsp;&nbsp;</span>All messy stuff below here, messier than above anyway, don't look and don't judge</a></span></li></ul></div>

# %%
import pandas as pd
import numpy as np
import seaborn as sns

from datetime import datetime

import shapely
from shapely.geometry import Point, MultiPoint
from shapely.ops import nearest_points

from sklearn.impute import SimpleImputer

from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.cluster import DBSCAN
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.metrics import silhouette_score

from sklearn.cluster import KMeans
from sklearn.neighbors import KNeighborsClassifier
from sklearn.pipeline import Pipeline

from sklearn.linear_model import LogisticRegression
import xgboost as xgb

from pactools import simulate_pac
from pactools.grid_search import ExtractDriver, AddDriverDelay
from pactools.grid_search import DARSklearn, MultipleArray
from pactools.grid_search import GridSearchCVProgressBar


pd.set_option('display.max_columns', None)


import matplotlib.pyplot as plt
from mpl_toolkits import mplot3d

# %matplotlib inline

# %%
train_raw = pd.read_csv('./datasets/train.csv')
test_raw = pd.read_csv('./datasets/test.csv')
spray_raw = pd.read_csv('./datasets/spray.csv')
weather_raw = pd.read_csv('./datasets/weather.csv')

# %%
#mapdata = np.loadtxt('./assets/mapdata_copyright_openstreetmap_contributors.txt')

#aspect = mapdata.shape[0] * 1.0 / mapdata.shape[1]
#lon_lat_box = (-88, -87.5, 41.6, 42.1)

# %% [markdown]
# # Cleaning Weather

# %%
weather_raw.head(20)
# Out:
#     Station        Date  Tmax  Tmin Tavg Depart  DewPoint WetBulb Heat Cool  \
# 0         1  2007-05-01    83    50   67     14        51      56    0    2
# 1         2  2007-05-01    84    52   68      M        51      57    0    3
# 2         1  2007-05-02    59    42   51     -3        42      47   14    0
# 3         2  2007-05-02    60    43   52      M        42      47   13    0
# 4         1  2007-05-03    66    46   56      2        40      48    9    0
# 5         2  2007-05-03    67    48   58      M        40      50    7    0
# 6         1  2007-05-04    66    49   58      4        41      50    7    0
# 7         2  2007-05-04    78    51    M      M        42      50    M    M
# 8         1  2007-05-05    66    53   60      5        38      49    5    0
# 9         2  2007-05-05    66    54   60      M        39      50    5    0
# 10        1  2007-05-06    68    49   59      4        30      46    6    0
# 11        2  2007-05-06    68    52   60      M        30      46    5    0
# 12        1  2007-05-07    83    47   65     10        41      54    0    0
# 13        2  2007-05-07    84    50   67      M        39      53    0    2
# 14        1  2007-05-08    82    54   68     12        58      62    0    3
# 15        2  2007-05-08    80    60   70      M        57      63    0    5
# 16        1  2007-05-09    77    61   69     13        59      63    0    4
# 17        2  2007-05-09    76    63   70      M        60      63    0    5
# 18        1  2007-05-10    84    56   70     14        52      60    0    5
# 19        2  2007-05-10    83    59   71      M        52      61    0    6
#
#    Sunrise Sunset CodeSum Depth Water1 SnowFall PrecipTotal StnPressure  \
# 0     0448   1849             0      M      0.0        0.00       29.10
# 1        -      -             M      M        M        0.00       29.18
# 2     0447   1850      BR     0      M      0.0        0.00       29.38
# 3        -      -   BR HZ     M      M        M        0.00       29.44
# 4     0446   1851             0      M      0.0        0.00       29.39
# 5        -      -      HZ     M      M        M        0.00       29.46
# 6     0444   1852      RA     0      M      0.0           T       29.31
# 7        -      -             M      M        M        0.00       29.36
# 8     0443   1853             0      M      0.0           T       29.40
# 9        -      -             M      M        M           T       29.46
# 10    0442   1855             0      M      0.0        0.00       29.57
# 11       -      -             M      M        M        0.00       29.62
# 12    0441   1856      RA     0      M      0.0           T       29.38
# 13       -      -             M      M        M        0.00       29.44
# 14    0439   1857      BR     0      M      0.0        0.00       29.29
# 15       -      -      HZ     M      M        M           T       29.36
# 16    0438   1858   BR HZ     0      M      0.0        0.13       29.21
# 17       -      -   BR HZ     M      M        M        0.02       29.28
# 18    0437   1859      BR     0      M      0.0        0.00       29.20
# 19       -      -   BR HZ     M      M        M        0.00       29.26
#
#    SeaLevel  ResultSpeed  ResultDir AvgSpeed
# 0     29.82          1.7         27      9.2
# 1     29.82          2.7         25      9.6
# 2     30.09         13.0          4     13.4
# 3     30.08         13.3          2     13.4
# 4     30.12         11.7          7     11.9
# 5     30.12         12.9          6     13.2
# 6     30.05         10.4          8     10.8
# 7     30.04         10.1          7     10.4
# 8     30.10         11.7          7     12.0
# 9     30.09         11.2          7     11.5
# 10    30.29         14.4         11     15.0
# 11    30.28         13.8         10     14.5
# 12    30.12          8.6         18     10.5
# 13    30.12          8.5         17      9.9
# 14    30.03          2.7         11      5.8
# 15    30.02          2.5          8      5.4
# 16    29.94          3.9          9      6.2
# 17    29.93          3.9          7      5.9
# 18    29.92          0.7         17      4.1
# 19    29.91          2.0          9      3.9

# %% [markdown]
# ## Missing 'Tavg' values

# %%
weather_temp = weather_raw.loc[(weather_raw['Tavg'] != 'M'), :].copy()

weather_temp['Tavg_Manual'] = (weather_temp['Tmax'] + weather_temp['Tmin'])/2

(weather_temp['Tavg_Manual'] - weather_temp['Tavg'].map(lambda x : int(x))).value_counts()
# Out:
# -0.5    1478
#  0.0    1455
# dtype: int64

# %%
# Checked against data documentation and of rows that have missing Tavg
# Manually solving for Tavg

weather_raw['Tavg_Manual'] = (weather_raw['Tmax'] + weather_raw['Tmin'])/2

weather_raw['Trange'] = weather_raw['Tmax'] - weather_raw['Tmin']

# %% [markdown]
# ## Missing WetBulb values and seeing correlation of Heat/Cool vs Tavg

# %%
weather_wet_dew = weather_raw.copy().loc[((weather_raw['WetBulb'] != 'M') & (weather_raw['Heat'] != 'M')), \
                                  ['DewPoint', 'WetBulb', 'Heat', 'Cool', 'Tavg_Manual']]
weather_wet_dew['WetBulb'] = weather_wet_dew['WetBulb'].map(lambda x : int(x))
weather_wet_dew['Heat'] = weather_wet_dew['Heat'].map(lambda x : int(x))
weather_wet_dew['Cool'] = weather_wet_dew['Cool'].map(lambda x : int(x))


# They're all pretty correlated to Tavg so just going to drop them

weather_wet_dew.corr()
# Out:
#              DewPoint   WetBulb      Heat      Cool  Tavg_Manual
# DewPoint     1.000000  0.972442 -0.773645  0.769713     0.882837
# WetBulb      0.972442  1.000000 -0.847774  0.834717     0.962280
# Heat        -0.773645 -0.847774  1.000000 -0.529397    -0.870932
# Cool         0.769713  0.834717 -0.529397  1.000000     0.877478
# Tavg_Manual  0.882837  0.962280 -0.870932  0.877478     1.000000

# %% [markdown]
# ## Amount of sunlight hours - just for fun?

# %%
weather_sun = weather_raw.loc[weather_raw['Station'] == 1].copy()


# Stupid 'Sunset' entries where they put minutes up to 60 instead of going to the next hour

weather_sun['Sunset'].unique()
# Out:
# array(['1849', '1850', '1851', '1852', '1853', '1855', '1856', '1857',
#        '1858', '1859', '1860', '1901', '1902', '1903', '1904', '1905',
#        '1906', '1907', '1908', '1909', '1910', '1911', '1912', '1913',
#        '1914', '1915', '1916', '1917', '1918', '1919', '1920', '1921',
#        '1922', '1923', '1924', '1925', '1926', '1927', '1928', '1929',
#        '1930', '1931', '1900', '1854', '1848', '1846', '1845', '1843',
#        '1842', '1840', '1839', '1837', '1835', '1834', '1832', '1831',
#        '1829', '1827', '1826', '1824', '1822', '1821', '1819', '1817',
#        '1815', '1814', '1812', '1810', '1809', '1807', '1805', '1803',
#        '1760', '1758', '1756', '1755', '1753', '1751', '1749', '1748',
#        '1746', '1744', '1742', '1741', '1739', '1737', '1735', '1734',
#        '1732', '1730', '1729', '1727', '1725', '1724', '1722', '1720',
#        '1719', '1717', '1715', '1714', '1712', '1711', '1709', '1707',
#        '1706', '1704', '1703', '1701', '1660', '1658', '1657', '1656',
#        '1654', '1653', '1651', '1650', '1649', '1647'], dtype=object)

# %%
# Cleaning aforementioned stupidity above

weather_sun['Sunset'] = weather_sun['Sunset'].map(lambda x : (str(int(x[0:2]) + 1) + '00') if x[2:4] == '60' else x)


weather_sun['Sunrise_Time'] = weather_sun['Sunrise'].map(lambda x : datetime.strptime(x, '%H%M'))
weather_sun['Sunset_Time'] = weather_sun['Sunset'].map(lambda x : datetime.strptime(x, '%H%M'))
weather_sun['Daylight_Hours'] = (weather_sun['Sunset_Time'] - weather_sun['Sunrise_Time']).map(lambda x : x.seconds / 60)


# Actually doesn't share that much correlation with average temperature, so may be we will want to add this in

weather_sun[['Daylight_Hours', 'Tavg_Manual']].corr()
# Out:
#                 Daylight_Hours  Tavg_Manual
# Daylight_Hours        1.000000     0.553301
# Tavg_Manual           0.553301     1.000000

# %%
# Joining it back into cleaning dataframe for weather

weather_raw = weather_raw.merge(weather_sun[['Date', 'Daylight_Hours']], on = 'Date')

# %% [markdown]
# ## Humidity

# %%
Tavg_C = ((weather_raw['Tavg_Manual'] - 32) * 5 / 9)
DewPoint_C = ((weather_raw['DewPoint'] - 32) * 5 / 9)
VapPress_Sat = np.exp((17.625 * Tavg_C) / (Tavg_C + 243.04))
VapPress_Act = np.exp((17.625 * DewPoint_C) / (DewPoint_C + 243.04))
R_Humidity = (VapPress_Act / VapPress_Sat) * 100

weather_raw['R_Humidity'] = R_Humidity

# %% [markdown]
# ## CodeSum

# %%
# CodeSum_dummies = pd.get_dummies(weather_raw['CodeSum'].str.split().apply(pd.Series).stack(dropna = False), prefix = 'CodeSum').sum(level = 0)

# CodeSum_dummies.columns

# weather_raw = weather_raw.join(CodeSum_dummies, how = 'left')

# %% [markdown]
# ## Looking at some other columns

# %%
# Dropping this column, only one station collects and it's all 0 anyway

weather_raw['Depth'].value_counts()
# Out:
# 0    1472
# M    1472
# Name: Depth, dtype: int64

# %%
# Dropping this column

weather_raw['Water1'].value_counts()
# Out:
# M    2944
# Name: Water1, dtype: int64

# %%
# Dropping this column, all near 0 anyway and seems like only one station collects it

weather_raw['SnowFall'].value_counts()
# Out:
# M      1472
# 0.0    1459
#   T      12
# 0.1       1
# Name: SnowFall, dtype: int64

# %%
# Trace is between 0.00 and 0.01

weather_raw['PrecipTotal'].unique()

# weather_raw['PrecipTotal'].value_counts()
# Out:
# array(['0.00', '  T', '0.13', '0.02', '0.38', '0.60', '0.14', '0.07',
#        '0.11', '0.09', '1.01', '0.28', '0.04', '0.08', '0.01', '0.53',
#        '0.19', '0.21', '0.32', '0.39', '0.31', '0.42', '0.27', '0.16',
#        '0.58', '0.93', '0.05', '0.34', '0.15', '0.35', 'M', '0.40',
#        '0.66', '0.30', '0.24', '0.43', '1.55', '0.92', '0.89', '0.17',
#        '0.03', '1.43', '0.97', '0.26', '1.31', '0.06', '0.46', '0.29',
#        '0.23', '0.41', '0.45', '0.83', '1.33', '0.91', '0.48', '0.37',
#        '0.88', '2.35', '1.96', '0.20', '0.25', '0.18', '0.67', '0.36',
#        '0.33', '1.28', '0.74', '0.76', '0.71', '0.95', '1.46', '0.12',
#        '0.52', '0.64', '0.22', '1.24', '0.72', '0.73', '0.65', '1.61',
#        '1.22', '0.50', '1.05', '2.43', '0.59', '2.90', '2.68', '1.23',
#        '0.62', '6.64', '3.07', '1.44', '1.75', '0.82', '0.80', '0.86',
#        '0.63', '0.55', '1.03', '0.70', '1.73', '1.38', '0.44', '1.14',
#        '1.07', '3.97', '0.87', '0.78', '1.12', '0.68', '0.10', '0.61',
#        '0.54', '1.19', '0.75', '0.84', '1.29', '0.81', '1.15', '1.49',
#        '1.57', '1.02', '1.30', '0.51', '0.85', '0.79', '0.77', '2.79',
#        '3.15', '3.64', '4.73', '1.60', '0.57', '2.24', '1.90', '1.06',
#        '1.88', '0.69', '2.17', '6.86', '0.49', '1.11', '1.21', '0.90',
#        '1.34', '0.47', '0.56', '3.66', '1.09', '1.25', '1.35', '2.20',
#        '1.48', '0.96', '1.16', '1.04', '2.03', '2.09', '1.26', '2.60',
#        '2.06', '3.31', '2.76', '1.82', '0.98', '1.58', '3.17', '1.18'],
#       dtype=object)

# %%
weather_raw['PrecipTotal'] = weather_raw['PrecipTotal'].replace('  T', 0.00)

# %%
sns.distplot(weather_raw.loc[(weather_raw['PrecipTotal'] != 'M'), 'PrecipTotal'].map(lambda x : float(x)))

# %%
weather_raw.loc[(weather_raw['PrecipTotal'] == 'M')]
# Out:
#      Station        Date  Tmax  Tmin Tavg Depart  DewPoint WetBulb Heat Cool  \
# 117        2  2007-06-28    73    61   67      M        56      61    0    2
# 119        2  2007-06-29    71    56   64      M        56      60    1    0
#
#     Sunrise Sunset CodeSum Depth Water1 SnowFall PrecipTotal StnPressure  \
# 117       -      -             M      M        M           M       29.43
# 119       -      -             M      M        M           M       29.47
#
#     SeaLevel  ResultSpeed  ResultDir AvgSpeed  Tavg_Manual  Trange  \
# 117    30.07         12.2          2     13.3         67.0      12
# 119    30.11          7.4          2      8.2         63.5      15
#
#      Daylight_Hours  R_Humidity
# 117           912.0   67.773364
# 119           912.0   76.551433

# %%
# No rain on both days, going to fill PrecipTotal as 0.0

weather_raw[:][114:124]
# Out:
#      Station        Date  Tmax  Tmin Tavg Depart  DewPoint WetBulb Heat Cool  \
# 114        1  2007-06-27    91    71   81     10        70      72    0   16
# 115        2  2007-06-27    89    71   80      M        69      72    0   15
# 116        1  2007-06-28    74    58   66     -5        55      60    0    1
# 117        2  2007-06-28    73    61   67      M        56      61    0    2
# 118        1  2007-06-29    70    56   63     -8        55      59    2    0
# 119        2  2007-06-29    71    56   64      M        56      60    1    0
# 120        1  2007-06-30    79    54   67     -5        46      56    0    2
# 121        2  2007-06-30    77    58   68      M        49      58    0    3
# 122        1  2007-07-01    75    54   65     -7        52      58    0    0
# 123        2  2007-07-01    76    61   69      M        51      59    0    4
#
#     Sunrise Sunset     CodeSum Depth Water1 SnowFall PrecipTotal StnPressure  \
# 114    0418   1931        TSRA     0      M      0.0        0.15       29.29
# 115       -      -  TSRA RA BR     M      M        M        0.35       29.36
# 116    0419   1931                 0      M      0.0        0.00       29.41
# 117       -      -                 M      M        M           M       29.43
# 118    0419   1931                 0      M      0.0        0.00       29.41
# 119       -      -                 M      M        M           M       29.47
# 120    0419   1931                 0      M      0.0        0.00       29.41
# 121       -      -                 M      M        M        0.00       29.46
# 122    0420   1931                 0      M      0.0        0.00       29.51
# 123       -      -                 M      M        M        0.00       29.56
#
#     SeaLevel  ResultSpeed  ResultDir AvgSpeed  Tavg_Manual  Trange  \
# 114    30.02          7.5         24      8.8         81.0      20
# 115    30.00          7.9         24      8.5         80.0      18
# 116    30.09         11.9          3     12.5         66.0      16
# 117    30.07         12.2          2     13.3         67.0      12
# 118    30.13          7.6          2      8.3         63.0      14
# 119    30.11          7.4          2      8.2         63.5      15
# 120    30.13          4.9          3      5.8         66.5      25
# 121    30.11          5.1          4      6.2         67.5      19
# 122    30.23          8.6          4      8.6         64.5      21
# 123    30.21          9.5          4      9.7         68.5      15
#
#      Daylight_Hours  R_Humidity
# 114           913.0   69.303018
# 115           913.0   69.197084
# 116           912.0   67.660165
# 117           912.0   67.773364
# 118           912.0   75.130394
# 119           912.0   76.551433
# 120           912.0   47.625640
# 121           912.0   51.499230
# 122           911.0   63.872349
# 123           911.0   53.597707

# %%
weather_raw['PrecipTotal'] = weather_raw['PrecipTotal'].replace('M', 0.00).map(lambda x : float(x))

# %%
# Meh, just going to impute mean into missing StnPressure values

sns.distplot(weather_raw.loc[(weather_raw['StnPressure'] != 'M'), 'StnPressure'].map(lambda x : float(x)))

# %%
# Sama sama, just going to impute mean into missing AvgSpeed values

sns.distplot(weather_raw.loc[(weather_raw['AvgSpeed'] != 'M'), 'AvgSpeed'].map(lambda x : float(x)))

# %%
imp_mean = SimpleImputer(missing_values = np.nan, strategy = 'mean')

# %%
weather_raw['StnPressure'] = weather_raw['StnPressure'].map(lambda x : np.nan if x == 'M' else x)
weather_raw['AvgSpeed'] = weather_raw['AvgSpeed'].map(lambda x : np.nan if x == 'M' else x)

weather_raw[['StnPressure', 'AvgSpeed']] = imp_mean.fit_transform(weather_raw[['StnPressure', 'AvgSpeed']])

# %%
weather_raw.dtypes
# Out:
# Station             int64
# Date               object
# Tmax                int64
# Tmin                int64
# Tavg               object
# Depart             object
# DewPoint            int64
# WetBulb            object
# Heat               object
# Cool               object
# Sunrise            object
# Sunset             object
# CodeSum            object
# Depth              object
# Water1             object
# SnowFall           object
# PrecipTotal       float64
# StnPressure       float64
# SeaLevel           object
# ResultSpeed       float64
# ResultDir           int64
# AvgSpeed          float64
# Tavg_Manual       float64
# Trange              int64
# Daylight_Hours    float64
# R_Humidity        float64
# dtype: object

# %%
weather_raw['Date_Station'] = weather_raw['Date'] + '_' + weather_raw['Station'].astype(str)

# %% [markdown]
# ## Exporting to a dataframe

# %%
# Do we want to feature engineer the codesum??

df_weather = weather_raw[['Date', 'Station', 'Date_Station', 'Tavg_Manual', 'Trange', 'DewPoint', \
                          'PrecipTotal', 'StnPressure', 'AvgSpeed', 'Daylight_Hours', 'R_Humidity']].copy()


#                          'CodeSum_BCFG', 'CodeSum_BR', 'CodeSum_DZ', 'CodeSum_FG', 'CodeSum_FG+', \
#                          'CodeSum_FU', 'CodeSum_GR', 'CodeSum_HZ', 'CodeSum_MIFG', 'CodeSum_RA', \
#                          'CodeSum_SN', 'CodeSum_SQ', 'CodeSum_TS', 'CodeSum_TSRA', 'CodeSum_VCFG', \
#                          'CodeSum_VCTS']].copy()

# %%
plt.figure(figsize = (10, 8))
sns.heatmap(df_weather.corr().abs(), cmap = sns.diverging_palette(150, 10, n = 100))
# Out:
# C:\Users\Raphael\Anaconda3\lib\site-packages\seaborn\palettes.py:777: DeprecationWarning: object of type <class 'float'> cannot be safely interpreted as an integer.
#   pal = _ColorPalette(pal(np.linspace(0, 1, n_colors)))
# C:\Users\Raphael\Anaconda3\lib\site-packages\seaborn\matrix.py:268: PendingDeprecationWarning:
# The label function will be deprecated in a future version. Use Tick.label1 instead.
#   fontsize = tick.label.get_size()

# %% [markdown]
# # Cleaning Train set

# %%
train_raw.head(1)
# Out:
#          Date                                            Address  \
# 0  2007-05-29  4100 North Oak Park Avenue, Chicago, IL 60634,...
#
#                   Species  Block           Street  Trap  \
# 0  CULEX PIPIENS/RESTUANS     41   N OAK PARK AVE  T002
#
#               AddressNumberAndStreet  Latitude  Longitude  AddressAccuracy  \
# 0  4100  N OAK PARK AVE, Chicago, IL  41.95469 -87.800991                9
#
#    NumMosquitos  WnvPresent
# 0             1           0

# %% [markdown]
# ## Grouping NumMosquitos and assorted other columns

# %%
train_pre = train_raw.groupby([col for col in train_raw.columns if col not in ['NumMosquitos', \
                                                                               'WnvPresent']]).sum().reset_index()

# %%
train_pre['WnvPresent'] = train_pre['WnvPresent'].map(lambda x : 1 if x > 0 else x)

train_pre['LatLong'] = [(x, y) for x, y in zip(train_pre['Latitude'], train_pre['Longitude'])]

train_pre['Coord'] = [Point(x, y) for x, y in zip(train_pre['Latitude'], train_pre['Longitude'])]

station_points = MultiPoint([Point(41.995, -87.933), Point(41.786, -87.752)])
train_pre['Nearest_Station'] = train_pre['Coord'].map(lambda x : 1 if nearest_points(station_points, x)[0] == \
                                                      station_points[0] else 2)

train_pre['Date_Station'] = train_pre['Date'] + '_' + train_pre['Nearest_Station'].astype(str)

train_pre['Year'] = train_raw['Date'].apply(lambda x : datetime.strptime(x, '%Y-%m-%d').year)
train_pre['Month'] = train_raw['Date'].apply(lambda x : datetime.strptime(x, '%Y-%m-%d').month)
train_pre['Day'] = train_raw['Date'].apply(lambda x : datetime.strptime(x, '%Y-%m-%d').day)

# %%
train_pre['Year'].unique()
# Out:
# array([2007, 2009, 2011, 2013], dtype=int64)

# %% [markdown]
# ## DBSCAN to cluster by Latitude, Longitude, and NumMosquitos

# %%
def dbscan(df, list_of_columns, eps, min_samples):
    
    df_cluster = df[list_of_columns]

    minmax = MinMaxScaler(feature_range = (0, 1))

    clusters = minmax.fit_transform(df_cluster)

    dbs = DBSCAN(eps = eps, min_samples = min_samples)
    dbs.fit(clusters)
    df['Cluster'] = dbs.labels_
    vals = df['Cluster'].value_counts()
    print(f'Silhouette Score: {silhouette_score(clusters, dbs.labels_)}')
    print(f'Number of outliers: {vals[-1]}')
    print(f'Number of clusters: {len(vals)}')

    fig = plt.figure(figsize = (20, 16))
    ax = plt.axes(projection = '3d')
    ax.scatter3D(df['Latitude'], df['Longitude'], df['NumMosquitos'], c = df['Cluster'], cmap = 'rainbow')
    ax.set_title(f'DBSCAN for {list_of_columns}\n\u03B5 = {eps} Min. Clusters = {min_samples}')
    plt.show()

# %%
# Split by species too?

train_cluster = train_pre.groupby(['Date', 'LatLong']).mean().copy()

# %%
print('\u03B5')
# Out:
# ε

# %%
dbscan(train_cluster, ['Latitude', 'Longitude', 'NumMosquitos'], 0.0350, 3)
# Out:
# Silhouette Score: 0.7770148283050481
# Number of outliers: 27
# Number of clusters: 95

# %%
# Lat-Long points that have more than 1 cluster

cluster_group_mean = train_cluster.groupby(['LatLong', 'Cluster']).mean()
cluster_group_count = train_cluster.groupby(['LatLong', 'Cluster']).count()

cluster_duplicated = cluster_group_mean.index.get_level_values('LatLong').duplicated(keep = False)

cluster_outliers = (cluster_group_mean.index.get_level_values('Cluster') == -1)

# %% [markdown]
# ### Checks for LatLongs with belong to more than 1 cluster

# %%
# Might actually want to delve into why these specific ones had such cancerous mosquitos
# Seems like 2007 was a terrible year for some places in terms of WNV prevalence

# (41.899229999999996, -87.716788) -1       2011.000000  7.000000  29.000000
#                                   43      2008.862069  7.750000  15.758621
# (41.9216, -87.666455)            -1       2007.000000  8.000000   1.000000
#                                   9       2007.000000  7.200000  15.533333
# (41.95469, -87.800991)           -1       2011.000000  7.000000  29.000000
#                                   11      2008.848485  7.560606  17.106061
# (41.957799, -87.930995)          -1       2007.000000  9.000000  18.000000
#                                   88      2009.595745  7.489362  15.666667
# (41.973845000000004, -87.805059) -1       2009.000000  8.000000  13.000000
#                                   32      2010.128205  7.427350  17.538462
# (41.974689, -87.890615)          -1       2008.500000  8.250000  22.500000
#                                   86      2009.653333  7.513333  15.720000
# (41.991429, -87.747113)          -1       2011.000000  7.000000  29.000000
#                                   31      2008.928571  7.696429  14.928571

# %%
cluster_group_count.loc[cluster_duplicated, :, :]
# Out:
#                                           Block  Latitude  Longitude  \
# LatLong                          Cluster
# (41.659112, -87.53869300000001)  -1           2         2          2
#                                   83         48        48         48
# (41.662014, -87.72460799999999)  -1           2         2          2
#                                   16         64        64         64
# (41.673408, -87.599862)          -1           6         6          6
#                                   69         57        57         57
#                                   84          3         3          3
# (41.702723999999996, -87.536497) -1           1         1          1
#                                   77         11        11         11
# (41.704572, -87.56566600000001)  -1           1         1          1
#                                   74         53        53         53
#                                   85          3         3          3
# (41.726465000000005, -87.585413) -1           3         3          3
#                                   72         54        54         54
#                                   79          3         3          3
#                                   82          3         3          3
# (41.728495, -87.60096300000001)  -1           1         1          1
#                                   18         36        36         36
# (41.798697, -87.736812)          -1           1         1          1
#                                   60         58        58         58
# (41.899229999999996, -87.716788) -1           1         1          1
#                                   43         58        58         58
# (41.9216, -87.666455)            -1           1         1          1
#                                   9          15        15         15
# (41.95469, -87.800991)           -1           1         1          1
#                                   11         66        66         66
# (41.957799, -87.930995)          -1           1         1          1
#                                   88         47        47         47
# (41.973845000000004, -87.805059) -1           1         1          1
#                                   32         39        39         39
# (41.974689, -87.890615)          -1           4         4          4
#                                   86         50        50         50
# (41.991429, -87.747113)          -1           1         1          1
#                                   31         56        56         56
#
#                                           AddressAccuracy  NumMosquitos  \
# LatLong                          Cluster
# (41.659112, -87.53869300000001)  -1                     2             2
#                                   83                   48            48
# (41.662014, -87.72460799999999)  -1                     2             2
#                                   16                   64            64
# (41.673408, -87.599862)          -1                     6             6
#                                   69                   57            57
#                                   84                    3             3
# (41.702723999999996, -87.536497) -1                     1             1
#                                   77                   11            11
# (41.704572, -87.56566600000001)  -1                     1             1
#                                   74                   53            53
#                                   85                    3             3
# (41.726465000000005, -87.585413) -1                     3             3
#                                   72                   54            54
#                                   79                    3             3
#                                   82                    3             3
# (41.728495, -87.60096300000001)  -1                     1             1
#                                   18                   36            36
# (41.798697, -87.736812)          -1                     1             1
#                                   60                   58            58
# (41.899229999999996, -87.716788) -1                     1             1
#                                   43                   58            58
# (41.9216, -87.666455)            -1                     1             1
#                                   9                    15            15
# (41.95469, -87.800991)           -1                     1             1
#                                   11                   66            66
# (41.957799, -87.930995)          -1                     1             1
#                                   88                   47            47
# (41.973845000000004, -87.805059) -1                     1             1
#                                   32                   39            39
# (41.974689, -87.890615)          -1                     4             4
#                                   86                   50            50
# (41.991429, -87.747113)          -1                     1             1
#                                   31                   56            56
#
#                                           WnvPresent  Nearest_Station  Year  \
# LatLong                          Cluster
# (41.659112, -87.53869300000001)  -1                2                2     2
#                                   83              48               48    48
# (41.662014, -87.72460799999999)  -1                2                2     2
#                                   16              64               64    64
# (41.673408, -87.599862)          -1                6                6     6
#                                   69              57               57    57
#                                   84               3                3     3
# (41.702723999999996, -87.536497) -1                1                1     1
#                                   77              11               11    11
# (41.704572, -87.56566600000001)  -1                1                1     1
#                                   74              53               53    53
#                                   85               3                3     3
# (41.726465000000005, -87.585413) -1                3                3     3
#                                   72              54               54    54
#                                   79               3                3     3
#                                   82               3                3     3
# (41.728495, -87.60096300000001)  -1                1                1     1
#                                   18              36               36    36
# (41.798697, -87.736812)          -1                1                1     1
#                                   60              58               58    58
# (41.899229999999996, -87.716788) -1                1                1     1
#                                   43              58               58    58
# (41.9216, -87.666455)            -1                1                1     1
#                                   9               15               15    15
# (41.95469, -87.800991)           -1                1                1     1
#                                   11              66               66    66
# (41.957799, -87.930995)          -1                1                1     1
#                                   88              47               47    47
# (41.973845000000004, -87.805059) -1                1                1     1
#                                   32              39               39    39
# (41.974689, -87.890615)          -1                4                4     4
#                                   86              50               50    50
# (41.991429, -87.747113)          -1                1                1     1
#                                   31              56               56    56
#
#                                           Month  Day
# LatLong                          Cluster
# (41.659112, -87.53869300000001)  -1           2    2
#                                   83         48   48
# (41.662014, -87.72460799999999)  -1           2    2
#                                   16         64   64
# (41.673408, -87.599862)          -1           6    6
#                                   69         57   57
#                                   84          3    3
# (41.702723999999996, -87.536497) -1           1    1
#                                   77         11   11
# (41.704572, -87.56566600000001)  -1           1    1
#                                   74         53   53
#                                   85          3    3
# (41.726465000000005, -87.585413) -1           3    3
#                                   72         54   54
#                                   79          3    3
#                                   82          3    3
# (41.728495, -87.60096300000001)  -1           1    1
#                                   18         36   36
# (41.798697, -87.736812)          -1           1    1
#                                   60         58   58
# (41.899229999999996, -87.716788) -1           1    1
#                                   43         58   58
# (41.9216, -87.666455)            -1           1    1
#                                   9          15   15
# (41.95469, -87.800991)           -1           1    1
#                                   11         66   66
# (41.957799, -87.930995)          -1           1    1
#                                   88         47   47
# (41.973845000000004, -87.805059) -1           1    1
#                                   32         39   39
# (41.974689, -87.890615)          -1           4    4
#                                   86         50   50
# (41.991429, -87.747113)          -1           1    1
#                                   31         56   56

# %% [markdown]
# ### Check for LatLongs that are clustered all as outliers

# %%
cluster_group_mean.loc[(cluster_outliers & (cluster_duplicated == False)), :]
# Out:
# Empty DataFrame
# Columns: [Block, Latitude, Longitude, AddressAccuracy, NumMosquitos, WnvPresent, Nearest_Station, Year, Month, Day]
# Index: []

# %%
cluster_group_count.loc[(cluster_outliers & (cluster_duplicated == False)), :]
# Out:
# Empty DataFrame
# Columns: [Block, Latitude, Longitude, AddressAccuracy, NumMosquitos, WnvPresent, Nearest_Station, Year, Month, Day]
# Index: []

# %% [markdown]
# ### Cleaning up clusters for mapping

# %%
cluster_mapping = cluster_group_mean.reset_index()

# %%
# Keeping only one for each of the cluster
# Might not be the best idea, some of these outliers are really because there were some cancerous mosquitos

cluster_mapping = cluster_mapping.drop_duplicates(subset = 'LatLong', keep = 'last')

# %%
# This is in case any LatLongs still only are clustered all as outliers

cluster_mapping[cluster_mapping['Cluster'] == -1]
# Out:
# Empty DataFrame
# Columns: [LatLong, Cluster, Block, Latitude, Longitude, AddressAccuracy, NumMosquitos, WnvPresent, Nearest_Station, Year, Month, Day]
# Index: []

# %%
cluster_dict = dict(zip(cluster_mapping['LatLong'], cluster_mapping['Cluster']))

# %% [markdown]
# # Cleaning Test set

# %%
# Same stuff as for train set

test_pre = test_raw.copy()

test_pre['Coord'] = [Point(x, y) for x, y in zip(test_pre['Latitude'], test_pre['Longitude'])]

station_points = MultiPoint([Point(41.995, -87.933), Point(41.786, -87.752)])

test_pre['Nearest_Station'] = test_pre['Coord'].map(lambda x : 1 if nearest_points(station_points, x)[0] == \
                                                    station_points[0] else 2)

test_pre['Date_Station'] = test_pre['Date'] + '_' + test_pre['Nearest_Station'].astype(str)

test_pre['LatLong'] = [(x, y) for x, y in zip(test_pre['Latitude'], test_pre['Longitude'])]

# %% [markdown]
# ## Mapping DBSCAN cluster into test set
#
# Would not recommend mapping the NumMosquitos based on clusters. Average of NumMosquito varies too much by year

# %%
cluster_dict = dict(zip(cluster_mapping['LatLong'], cluster_mapping['Cluster']))
train_pre['Cluster'] = train_pre['LatLong'].map(cluster_dict)

# %%
train_pre['Cluster'].unique()
# Out:
# array([ 4,  5,  7,  9,  1,  8, 10,  0,  2, 11, 13, 14, 15, 12,  3,  6, 21,
#        22, 34, 35, 24, 20, 25, 17, 26, 27, 28, 29, 16, 31, 19, 30, 33, 23,
#        36, 32, 18, 39, 40, 38, 37, 41, 43, 46, 42, 44, 45, 47, 48, 55, 68,
#        63, 53, 66, 62, 65, 67, 61, 64, 60, 59, 58, 56, 57, 54, 52, 51, 50,
#        49, 71, 73, 84, 82, 70, 85, 72, 75, 81, 80, 78, 76, 77, 83, 87, 86,
#        88, 89, 91, 90, 92, 93], dtype=int64)

# %%
knn = KNeighborsClassifier(n_neighbors = 1)

knn.fit(train_pre[['Latitude', 'Longitude']], train_pre['Cluster'])

test_pre['Cluster'] = knn.predict(test_pre[['Latitude', 'Longitude']])

# %%
cluster_mosquito = cluster_mapping.groupby('Cluster').mean().reset_index()

mosquito_proportion = dict(zip(cluster_mosquito['Cluster'], cluster_mosquito['NumMosquitos']))


mosquito_dict = dict(train_pre.groupby('Species').sum()['NumMosquitos'].apply(lambda x : x / train_pre.groupby('Species').sum()['NumMosquitos'].sum()))
mosquito_dict['UNSPECIFIED CULEX'] = 1

# %%
test_pre['NumMosquitos_Total'] = test_pre['Cluster'].map(mosquito_dict)

test_pre['Species_Proportion'] = test_pre['Species'].map(mosquito_proportion)
test_pre['NumMosquitos_Proportion'] = test_pre['NumMosquitos_Total'] * test_pre['Species_Proportion']

# %% [markdown]
# # Merging weather data with train/test set

# %% [markdown]
# ## Function for making rolling average of weather

# %%
# Function to make rolling average

def weather_moving_average(df, cols_mean, cols_sum, start, end):
    
    suffix = ''.join(['_', str(start), '_', str(end)])
   
    stations = df['Station'].unique()
    
    cols_mean_name = [cols + '_mean' + suffix for cols in cols_mean]
    cols_sum_name = [cols + '_sum' + suffix for cols in cols_sum]
    
    new_cols = []
    new_cols.extend(cols_mean_name)
    new_cols.extend(cols_sum_name)
    new_cols.extend(['Date_Station'])
      
    df_rolling = pd.DataFrame(None, columns = new_cols)
    
    for station in stations:
        station_mean = df.loc[(df['Station'] == station), cols_mean].rolling(end - start).mean().shift(start)
        station_mean.columns = cols_mean_name
        
        station_sum = df.loc[(df['Station'] == station), cols_sum].rolling(end - start).sum().shift(start)
        station_sum.columns = cols_sum_name
        
        df_station = pd.concat([station_mean, station_sum], axis = 1)
        df_station['Date_Station'] = df.loc[(df['Station'] == station), 'Date_Station']
        
        df_rolling = df_rolling.append(df_station)
    
    df = df.merge(df_rolling, on = 'Date_Station')
        
    return df

# %%
weather_moving_average(df_weather, ['Tavg_Manual', 'Trange', 'DewPoint', 'StnPressure', \
                                    'AvgSpeed', 'Daylight_Hours', 'R_Humidity'], ['PrecipTotal'], 0, 21)
# Out:
#             Date  Station  Date_Station  Tavg_Manual  Trange  DewPoint  \
# 0     2007-05-01        1  2007-05-01_1         66.5      33        51
# 1     2007-05-01        2  2007-05-01_2         68.0      32        51
# 2     2007-05-02        1  2007-05-02_1         50.5      17        42
# 3     2007-05-02        2  2007-05-02_2         51.5      17        42
# 4     2007-05-03        1  2007-05-03_1         56.0      20        40
# 5     2007-05-03        2  2007-05-03_2         57.5      19        40
# 6     2007-05-04        1  2007-05-04_1         57.5      17        41
# 7     2007-05-04        2  2007-05-04_2         64.5      27        42
# 8     2007-05-05        1  2007-05-05_1         59.5      13        38
# 9     2007-05-05        2  2007-05-05_2         60.0      12        39
# 10    2007-05-06        1  2007-05-06_1         58.5      19        30
# 11    2007-05-06        2  2007-05-06_2         60.0      16        30
# 12    2007-05-07        1  2007-05-07_1         65.0      36        41
# 13    2007-05-07        2  2007-05-07_2         67.0      34        39
# 14    2007-05-08        1  2007-05-08_1         68.0      28        58
# 15    2007-05-08        2  2007-05-08_2         70.0      20        57
# 16    2007-05-09        1  2007-05-09_1         69.0      16        59
# 17    2007-05-09        2  2007-05-09_2         69.5      13        60
# 18    2007-05-10        1  2007-05-10_1         70.0      28        52
# 19    2007-05-10        2  2007-05-10_2         71.0      24        52
# 20    2007-05-11        1  2007-05-11_1         60.5      19        42
# 21    2007-05-11        2  2007-05-11_2         61.0      24        44
# 22    2007-05-12        1  2007-05-12_1         55.0      18        36
# 23    2007-05-12        2  2007-05-12_2         56.0      18        37
# 24    2007-05-13        1  2007-05-13_1         56.0      26        33
# Out:
#          Date  Station  Date_Station  Tavg_Manual  Trange  DewPoint  \
# 0  2007-05-01        1  2007-05-01_1         66.5      33        51
# 1  2007-05-01        2  2007-05-01_2         68.0      32        51
# 2  2007-05-02        1  2007-05-02_1         50.5      17        42
# 3  2007-05-02        2  2007-05-02_2         51.5      17        42
# 4  2007-05-03        1  2007-05-03_1         56.0      20        40
#
#    PrecipTotal  StnPressure  AvgSpeed  Daylight_Hours  R_Humidity
# 0          0.0        29.10       9.2           841.0   57.422798
# 1          0.0        29.18       9.6           841.0   54.526426
# 2          0.0        29.38      13.4           843.0   72.526813
# 3          0.0        29.44      13.4           843.0   69.892062
# 4          0.0        29.39      11.9           845.0   54.874919

# %% [markdown]
# ## Function to merge rolling average weather into train/test set

# %%
def df_add_weather(df_X, df_weather, cols_mean, cols_sum, start, end, cluster, num_mosquitos):
    df_weather_roll = weather_moving_average(df_weather, cols_mean, cols_sum, start, end)
    df_weather_roll = df_weather_roll.drop(columns = cols_sum)
    df_weather_roll = df_weather_roll.drop(columns = cols_mean)

    df_weather_roll = df_weather_roll.drop(columns = ['Date', 'Station'])

    df_species = df_X['Species'].str.get_dummies()
    
    if cluster == True:
        df_species['Cluster'] = df_X['Cluster']
        df_species = pd.get_dummies(df_species, columns = ['Cluster'])
    else:
        pass
    
    if num_mosquitos == True:
        df_species['NumMosquitos'] = df_X[num_mosquitos]
    else:
        pass
    
    df_species['Date_Station'] = df_X['Date_Station']

    
    df_X_weather = df_species.merge(df_weather_roll, how = 'left', on = 'Date_Station')
    df_X_weather = df_X_weather.drop(columns = ['Date_Station'])
    
    return df_X_weather

# %% [markdown]
# # Preparing for modelling

# %% [markdown]
# ## Getting sets of X variables

# %%
X_dict = {
    1 : [['Tavg_Manual', 'Trange', 'DewPoint', 'StnPressure', 'AvgSpeed', 'Daylight_Hours', \
          'R_Humidity', 'PrecipTotal'], [], 0, 14, True, False],
    2 : [['Tavg_Manual', 'Trange', 'DewPoint', 'StnPressure', 'AvgSpeed', 'Daylight_Hours', \
          'R_Humidity'], ['PrecipTotal'], 0, 14, True, False],
    3 : [['Tavg_Manual', 'Trange', 'DewPoint', 'StnPressure', 'AvgSpeed', \
          'R_Humidity'], ['PrecipTotal', 'Daylight_Hours'], 0, 14, True, False],
    4 : [['Tavg_Manual', 'Trange', 'DewPoint', 'StnPressure', 'AvgSpeed', 'Daylight_Hours', \
          'R_Humidity', 'PrecipTotal'], [], 0, 21, True, False],
    5 : [['Tavg_Manual', 'Trange', 'DewPoint', 'StnPressure', 'AvgSpeed', 'Daylight_Hours', \
          'R_Humidity'], ['PrecipTotal'], 0, 21, True, False],
    6 : [['Tavg_Manual', 'Trange', 'DewPoint', 'StnPressure', 'AvgSpeed', \
          'R_Humidity'], ['PrecipTotal', 'Daylight_Hours'], 0, 21, True, False],
    7 : [['Tavg_Manual', 'Trange', 'DewPoint', 'StnPressure', 'AvgSpeed', 'Daylight_Hours', \
          'R_Humidity', 'PrecipTotal'], [], 0, 14, False, False],
    8 : [['Tavg_Manual', 'Trange', 'DewPoint', 'StnPressure', 'AvgSpeed', 'Daylight_Hours', \
          'R_Humidity'], ['PrecipTotal'], 0, 14, False, False],
    9 : [['Tavg_Manual', 'Trange', 'DewPoint', 'StnPressure', 'AvgSpeed', \
          'R_Humidity'], ['PrecipTotal', 'Daylight_Hours'], 0, 14, False, False],
    10: [['Tavg_Manual', 'Trange', 'DewPoint', 'StnPressure', 'AvgSpeed', 'Daylight_Hours', \
           'R_Humidity', 'PrecipTotal'], [], 0, 21, False, False],
    11: [['Tavg_Manual', 'Trange', 'DewPoint', 'StnPressure', 'AvgSpeed', 'Daylight_Hours', \
           'R_Humidity'], ['PrecipTotal'], 0, 21, False, False],
    12: [['Tavg_Manual', 'Trange', 'DewPoint', 'StnPressure', 'AvgSpeed', \
           'R_Humidity'], ['PrecipTotal', 'Daylight_Hours'], 0, 21, False, False],
#     13 : [['Tavg_Manual', 'Trange', 'DewPoint', 'StnPressure', 'AvgSpeed', 'Daylight_Hours', \
#           'R_Humidity', 'PrecipTotal'], [], 0, 14, False],
#     14 : [['Tavg_Manual', 'Trange', 'DewPoint', 'StnPressure', 'AvgSpeed', 'Daylight_Hours', \
#           'R_Humidity'], ['PrecipTotal'], 0, 14, False],
#     15 : [['Tavg_Manual', 'Trange', 'DewPoint', 'StnPressure', 'AvgSpeed', \
#           'R_Humidity'], ['PrecipTotal', 'Daylight_Hours'], 0, 14, False],


         }

X_dict_names = {
    1 : 'Clustered - Rolling 0 to 14 days Weather: All Average',
    2 : 'Clustered - Rolling 0 to 14 days Weather: Mean PrecipTotal',
    3 : 'Clustered - Rolling 0 to 14 days Weather: Mean PrecipTotal + Daylight_Hours',
    4 : 'Clustered - Rolling 0 to 21 days Weather: All Average',
    5 : 'Clustered - Rolling 0 to 21 days Weather: Mean PrecipTotal',
    6 : 'Clustered - Rolling 0 to 21 days Weather: Mean PrecipTotal + Daylight_Hours',
    7 : 'No Cluster - Rolling 0 to 14 days Weather: All Average',
    8 : 'No Cluster - Rolling 0 to 14 days Weather: Mean PrecipTotal',
    9 : 'No Cluster - Rolling 0 to 14 days Weather: Mean PrecipTotal + Daylight_Hours',
    10: 'No Cluster - Rolling 0 to 21 days Weather: All Average',
    11: 'No Cluster - Rolling 0 to 21 days Weather: Mean PrecipTotal',
    12: 'No Cluster - Rolling 0 to 21 days Weather: Mean PrecipTotal + Daylight_Hours',
}

# Initialising empty dictionary to store slices of X and Y training and test sets, based on above X_dict keys\n,
    
X_train = {}
X_test = {}
y_train = {}
y_test = {}
X_all = {}
y_all = {}
test_all = {}

# %%
# For loop to populate dictionaries of X and Y training and test sets,

for i in X_dict.keys():
    X_train[i], X_test[i], y_train[i], y_test[i] = \
    train_test_split(df_add_weather(train_pre, df_weather, X_dict[i][0], X_dict[i][1], X_dict[i][2], \
                                    X_dict[i][3], X_dict[i][4], X_dict[i][5]), \
                     train_pre['WnvPresent'], test_size = 0.25, stratify = train_pre['WnvPresent'], \
# 6053              29.277857            6.907143                804.857143
#
#       R_Humidity_mean_0_14  PrecipTotal_mean_0_14
# 4903             69.523192               0.167857
# 6913             64.632758               0.132143
# 1968             64.287923               0.235000
# 906              59.718335               0.067143
# 790              61.282584               0.037143
# 5401             60.660154               0.015714
# 5110             56.490582               0.027857
# 3613             62.303331               0.094286
# 4055             60.895591               0.028571
# 1940             64.287923               0.235000
# 3791             60.960002               0.057857
# 8410             61.426649               0.055000
# 7243             57.545444               0.002857
# 6848             64.632758               0.132143
# 7418             59.555537               0.014286
# 3439             62.388355               0.036429
# 770              59.718335               0.067143
# 2284             57.199803               0.071429
# 6908             70.278385               0.210714
# 4855             69.523192               0.167857
# 3045             63.908046               0.169286
# 4772             63.707763               0.341429
# 2331             57.484563               0.071429
# 3615             58.965667               0.146429
# 6637             60.570567               0.120714
# 4615             71.740151               0.036429
# 1075             63.327806               0.242143
# 3840             60.466108               0.023571
# 2952             59.863067               0.167857
# 5928             64.339700               0.124286
# ...                    ...                    ...
# 5688             66.515329               0.125714
# 2162             61.775199               0.071429
# 2961             59.863067               0.167857
# 334              58.774529               0.076429
# 7016             63.727630               0.065714
# 3800             60.960002               0.057857
# 863              59.718335               0.067143
# 35               59.785189               0.149286
# 1739             72.468293               0.485000
# 3867             60.466108               0.023571
# 1787             73.520989               0.444286
# 1370             67.724281               0.225714
# 6853             64.632758               0.132143
# 1224             67.724281               0.225714
# 445              58.291453               0.101429
# 6921             64.632758               0.132143
# 6915             64.632758               0.132143
# 1422             67.724281               0.225714
# 3048             63.908046               0.169286
# 4062             60.895591               0.028571
# 5766             66.515329               0.125714
# 5295             60.660154               0.015714
# 6366             68.566228               0.053571
# 4534             71.740151               0.036429
# 7330             57.545444               0.002857
# 7607             62.190097               0.045000
# 4235             69.339414               0.244286
# 2855             58.254352               0.167857
# 5920             64.339700               0.124286
# 6053             63.418264               0.062143
#
# [6356 rows x 106 columns]

# %% [markdown]
# ## Preparing a dictionary to append model data

# %%
# Initialising empty dictionary to store model parameters and results

model_dict = {}

# %%
# Defining dictionary of pipeline transformers and classifiers

pipe_dict = {'ss' : ('ss', StandardScaler()),
             'logreg' : ('logreg', LogisticRegression(solver = 'lbfgs')),
             'xgc' : ('xgc', xgb.XGBClassifier(objective = 'binary:logistic')),

            }


# Defining dictionary of parameters for pipeline transformers

param_dict = {'xgc_params' : {'xgc__eval_metric' : ['auc'],
                              'xgc__subsample' : [0.5, 0.7, 0.9], 
                              'xgc__colsample_bytree' : [0.5, 0.7, 0.9], 
                              'xgc__learning_rate' : [0.10, 0.20],
                              'xgc__max_depth' : [3, 4, 5], 
                              'xgc__n_estimators' : [1000, 1500, 2000, 2500, 3000],

                             }, \
              'xgc_params_MADNESS' : {'xgc__objective' : ['binary:logistic'],
                              'xgc__eval_metric' : ['auc'],
                              'xgc__subsample' : [0.4, 0.5, 0.6, 0.7, 0.8, 0.9], 
                              'xgc__colsample_bytree' : [0.4, 0.5, 0.6, 0.7, 0.8, 0.9], 
                              'xgc__learning_rate' : [0.05, 0.10, 0.15, 0.20],
                              'xgc__max_depth' : [2, 3, 4, 5, 6], 
                              'xgc__n_estimators' : [1000, 1500, 2000],
                              'xgc__n_jobs' : [-1]
                             }, \

             }


# Defining dictionary of more descriptive names for pipeline transformers and classifiers

pipe_dict_names = {'xgc' : 'XGB Classifier',
                  }

# %%
# Defining function to run pipeline model for each set of X stored in X_dict above and populate model_dict with model \
# parameters and results

def model_making(X_dict, scaler, classifier):
    for i in X_dict.keys():
        # Defining model_name to be used as key for model_dict
        model_name = '_'.join([classifier, str(i)])
        
        # Initialising empty dictionary (within the model_dict dictionary) to store instanced model parameters and results
        model_dict[model_name] = {}
        
        if scaler == None:
            model_dict[model_name]['name'] = ' '.join([pipe_dict_names[classifier], X_dict_names[i]])
            model_dict[model_name]['pipe'] = Pipeline([pipe_dict[classifier]])
        else:
            model_dict[model_name]['name'] = ' '.join([pipe_dict_names[classifier], X_dict_names[i], pipe_dict_names[scaler]])
            model_dict[model_name]['pipe'] = Pipeline([pipe_dict[scaler], pipe_dict[classifier]])            
        
        
        model_dict[model_name]['params'] = param_dict[classifier + '_params'].copy()

        
        # Defining vectoriser parameter grid for model instance

        # Defining model for GridSearchCV using above pipeline and parameters
        model_dict[model_name]['model'] = GridSearchCVProgressBar(model_dict[model_name]['pipe'], \
                                                       param_grid = model_dict[model_name]['params'],
                                                       cv = 3,
                                                      verbose = 2, n_jobs = -1)
#         except:
#             model_dict[model_name]['model'] = GridSearchCV(model_dict[model_name]['pipe'], \
#                                                        param_grid = model_dict[model_name]['params'],
#                                                        cv = 3,
#                                                       verbose = 1)

        # Fitting model for GridSearchCV
        model_dict[model_name]['model'].fit(X_train[i], y_train[i])
        
        # Storing cross-validation scores and best parameters for model instance
        model_dict[model_name]['train_score'] = model_dict[model_name]['model'].best_score_ 
        model_dict[model_name]['best_params'] = model_dict[model_name]['model'].best_params_
        model_dict[model_name]['test_score'] = model_dict[model_name]['model'].best_estimator_.score(X_test[i], y_test[i])

        # Storing predict_probability from best scoring model instance
        model_dict[model_name]['best_model'] = model_dict[model_name]['model'].best_estimator_.fit(X_all[i], y_all[i])
        model_dict[model_name]['train_pred_proba'] = [i[1] for i in model_dict[model_name]['best_model'].predict_proba(X_all[i])]
        model_dict[model_name]['train_pred_df'] = pd.DataFrame({'True_Values' : y_all[i],
                                                                'Pred_Probs' : model_dict[model_name]['train_pred_proba']})
        model_dict[model_name]['test_pred_proba'] = [i[1] for i in model_dict[model_name]['best_model'].predict_proba(test_all[i])]

        # Storing coefficients from best scoring model instance
        # Nested in a try/except block as not all classifiers return coefficients
        try:
            feats = np.array(model_dict[model_name]['model'].best_estimator_.named_steps[vect].get_feature_names())
            coefs = model_dict[model_name]['model'].best_estimator_.named_steps[regr].coef_.ravel()

            feat_coefs = {'Features': feats, 'Coefficients': coefs}
            model_dict[model_name]['coefs'] = pd.DataFrame(feat_coefs)
        except:
            model_dict[model_name]['coefs'] = np.nan
            
        # Printing scores and best parameters for model instance
        print(model_dict[model_name]['name'], '\n')
        print(f'Score on Train Set:', model_dict[model_name]['train_score'])
        print(f'Best Parameters:', model_dict[model_name]['best_params'])
        print(f'Score on Test Set:', model_dict[model_name]['test_score'], '\n\n')

# %% [markdown]
# # YOLO time

# %%
model_making(X_dict, scaler = None, classifier = 'xgc')
# Out:
# Fitting 3 folds for each of 270 candidates, totalling 810 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  17 tasks      | elapsed:   43.2s

# %%
model_dict['xgc_1']['best_model'].predict_proba(X_all[1])
# Out:
# array([[0.99417144, 0.00582854],
#        [0.99535424, 0.00464579],
#        [0.99535424, 0.00464579],
#        ...,
#        [0.9809071 , 0.01909291],
#        [0.9809071 , 0.01909291],
#        [0.9809071 , 0.01909291]], dtype=float32)

# %%
clf.best_estimator_.predict_proba(X_all[12])
# Out:
# array([[0.99313945, 0.00686055],
#        [0.99429214, 0.00570785],
#        [0.99429214, 0.00570785],
#        ...,
#        [0.9770575 , 0.02294249],
#        [0.9770575 , 0.02294249],
#        [0.9770575 , 0.02294249]], dtype=float32)

# %%
clf.best_estimator_.fit(X_all[12], y_all[12])
# Out:
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#               colsample_bynode=1, colsample_bytree=1, gamma=0,
#               learning_rate=0.1, max_delta_step=0, max_depth=3,
#               min_child_weight=1, missing=None, n_estimators=100, n_jobs=1,
#               nthread=None, objective='binary:logistic', random_state=0,
#               reg_alpha=0, reg_lambda=1, scale_pos_weight=1, seed=None,
#               silent=None, subsample=1, verbosity=1, xgc__eval_metric='auc',
#               xgc__subsample=0.7)

# %%
predict = [i[1] for i in clf.best_estimator_.predict_proba(test_all[12])]

output = pd.DataFrame(zip(test_pre['Id'], predict), columns = ['Id', 'WnvPresent'])

# %%
output.to_csv('./datasets/YOLO_20191105_0747_xgc_05_21_sum_precip-sunlight_w-clusters_gridsearched.csv', index = False)

# %%
xgc = xgb.XGBClassifier(objective ='binary:logistic', subsample = 0.5, colsample_bytree = 0.5, learning_rate = 0.1,
                max_depth = 5, n_estimators = 2000)

# %%
i = 12

xgc.fit(X_train[i], y_train[i])
print(xgc.score(X_train[i], y_train[i]))
print(xgc.score(X_test[i], y_test[i]))
print(xgc.score(X_all[i], y_all[i]))
xgc.predict(test_all[i])

# %%
xgc.fit(X_all[i], y_all[i])

predict = [num[1] for num in xgc.predict_proba(test_all[i])]

output = pd.DataFrame(zip(test_pre['Id'], predict), columns = ['Id', 'WnvPresent'])

# %%
output.to_csv('./datasets/YOLO_20191105_1934_xgc_05_21_sum_precip-sunlight_w-clusters.csv', index = False)

# %%
output['WnvPresent'].value_counts()

# %%
list_of_columns = ['Tavg_Manual', 'Trange', 'DewPoint', 'PrecipTotal', 'StnPressure', 'AvgSpeed', \
                   'Daylight_Hours', 'R_Humidity']

#'CodeSum_BCFG', 'CodeSum_BR', 'CodeSum_DZ', 'CodeSum_FG', \
#                   'CodeSum_FG+', 'CodeSum_FU', 'CodeSum_GR', 'CodeSum_HZ', 'CodeSum_MIFG', 'CodeSum_RA', \
#                   'CodeSum_SN', 'CodeSum_SQ',  'CodeSum_TS', 'CodeSum_TSRA', 'CodeSum_VCFG', 'CodeSum_VCTS']

# %%
train_8_14 = df_add_weather(train_pre, df_weather, list_of_columns, '_8_14', 8, 14)

# %%
test_8_14 = df_add_weather(test_pre, df_weather, list_of_columns, '_8_14', 8, 14).drop(columns = 'UNSPECIFIED CULEX')

# %%
test_8_14.head()

# %% [markdown]
# # YOLO... err.. modelling time

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import roc_auc_score, classification_report
from sklearn.model_selection import train_test_split, GridSearchCV

from sklearn.preprocessing import StandardScaler

# %%
ss = StandardScaler()

# %%
output.to_csv('./datasets/YOLO_20191104_1137_logreg_8_14.csv', index = False)

# %%
logreg = LogisticRegression()

logreg.fit(ss.fit_transform(X_train[1]), y_train[1])
print(logreg.score(ss.fit_transform(X_train[1]), y_train[1]))
print(logreg.score(ss.fit_transform(X_test[1]), y_test[1]))

predict = [i[1] for i in logreg.predict_proba(test_all[1])]

output = pd.DataFrame(zip(test_pre['Id'], predict), columns = ['Id', 'WnvPresent'])

#output.to_csv('./datasets/YOLO_20191104_1149_logreg_0_14.csv', index = False)

# %% [markdown]
# # All messy stuff below here, messier than above anyway, don't look and don't judge

# %%
from sklearn.naive_bayes import MultinomialNB
from sklearn.ensemble import RandomForestClassifier

# %%
test = df_add_weather(test_pre, df_weather , X_dict[1][0], X_dict[1][1], X_dict[1][2]).drop(columns = 'UNSPECIFIED CULEX')

# %%
test.head()

# %%
train_pre.groupby('LatLong').mean().loc[:, 'NumMosquitos']

# %%
trap_points = MultiPoint(train_pre['Coord'].tolist())

# %%
test_pre['LatLong'].map(mos_dict).isnull().sum()

# %%
rf = RandomForestClassifier()

# %%
for i in X_dict.keys():
    rf.fit(X_train[i], y_train[i])
    print(f'X variable set: {i}\n')
    print(rf.score(X_train[i], y_train[i]))
    print(rf.score(X_test[i], y_test[i]))
    print(rf.score(X_all[i], y_all[i]))

# %%
rf.score(X_train[2], y_train[2])

# %%
rf.score(X_test[2], y_test[2])

# %%
rf.score(X_all[2], y_all[2])

# %%
rf.fit(X_all[12], y_all[12])


predict = [i[1] for i in rf.predict_proba(test_all[1])]

output = pd.DataFrame(zip(test_pre['Id'], predict), columns = ['Id', 'WnvPresent'])

# %%
X_asdf = X_all[1].copy()
X_asdf['WnvPresent'] = train_pre['WnvPresent']

# %%
X_asdf.corr()

# %%
output.to_csv('./datasets/YOLO_20191105_1524_rf_05_21_sum_precip_sunlight.csv', index = False)

# %%
rf = RandomForestClassifier()

rf.fit(X_0014_train, y_0014_train)

rf.score(X_0014_train, y_0014_train)
rf.score(X_0014_test, y_0014_test)

rf.fit(X_0014, y_0014)

predict = [i[1] for i in rf.predict_proba(test_0014)]

output = pd.DataFrame(zip(test_pre['Id'], predict), columns = ['Id', 'WnvPresent'])

output.to_csv('./datasets/YOLO_20191104_1153_rf_0_14.csv', index = False)

# %%
nb = MultinomialNB()

# %%
nb.fit(X_train, y_train)

# %%
nb.score(X_train, y_train)

# %%
yolo2.columns = ['Id', 'WnvPresent']

# %%
yolo2.to_csv('./datasets/YOLO_2.csv', index = False)

# %%
from matplotlib.collections import PatchCollection
from descartes import PolygonPatch

#traps = [PolygonPatch(i.buffer(0.001)) for i in train_pre['Coord']]
#stations = [PolygonPatch(j.buffer(0.01)) for j in station_points]

#plt.figure(figsize = (20, 20))
#plt.imshow(mapdata, cmap=plt.get_cmap('gray'), extent=lon_lat_box, aspect=aspect)
#ax = plt.gca()


#ax.add_collection(PatchCollection(traps))

#ax.scatter(y = [41.995, 41.786], x = [-87.933, -87.752], s = 100, c ='red')

# %%
test_raw.head()
